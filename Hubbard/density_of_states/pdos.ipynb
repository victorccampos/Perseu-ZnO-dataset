# %%
import matplotlib.pyplot as plt 
import numpy as np
plt.style.use(r'/home/jvc/QEspresso7.2/ZnO_database/mpl_themes/computermodern.mplstyle')

# %%
! ls *atm*
# Out:
# 'ZnO-3.27-1.61-111.pdos_atm#1(Zn)_wfc#1(s)'
# 'ZnO-3.27-1.61-111.pdos_atm#1(Zn)_wfc#2(p)'
# 'ZnO-3.27-1.61-111.pdos_atm#1(Zn)_wfc#3(d)'
# 'ZnO-3.27-1.61-111.pdos_atm#2(Zn)_wfc#1(s)'
# 'ZnO-3.27-1.61-111.pdos_atm#2(Zn)_wfc#2(p)'
# 'ZnO-3.27-1.61-111.pdos_atm#2(Zn)_wfc#3(d)'
# 'ZnO-3.27-1.61-111.pdos_atm#3(O)_wfc#1(s)'
# 'ZnO-3.27-1.61-111.pdos_atm#3(O)_wfc#2(p)'
# 'ZnO-3.27-1.61-111.pdos_atm#4(O)_wfc#1(s)'
# 'ZnO-3.27-1.61-111.pdos_atm#4(O)_wfc#2(p)'

# %%
! head *atm*
# Out:
# ==> ZnO-3.27-1.61-111.pdos_atm#1(Zn)_wfc#1(s) <==
# # E (eV)   ldos(E)   pdos(E)
#  -10.077  0.123E-03  0.123E-03
#  -10.067  0.183E-01  0.183E-01
#  -10.057  0.370E+00  0.370E+00
#  -10.047  0.108E+01  0.108E+01
#  -10.037  0.784E+00  0.784E+00
#  -10.027  0.309E+00  0.309E+00
#  -10.017  0.145E+00  0.145E+00
#  -10.007  0.495E+00  0.495E+00
#   -9.997  0.543E+00  0.543E+00
#
# ==> ZnO-3.27-1.61-111.pdos_atm#1(Zn)_wfc#2(p) <==
# # E (eV)   ldos(E)   pdos(E)    pdos(E)    pdos(E)
#  -10.077  0.665E-07  0.665E-07  0.136E-21  0.136E-21
#  -10.067  0.106E-04  0.106E-04  0.399E-17  0.399E-17
#  -10.057  0.425E-03  0.425E-03  0.295E-12  0.295E-12
#  -10.047  0.911E-02  0.911E-02  0.297E-08  0.297E-08
#  -10.037  0.438E-01  0.438E-01  0.404E-05  0.404E-05
#  -10.027  0.315E-01  0.300E-01  0.744E-03  0.744E-03
#  -10.017  0.417E-01  0.456E-02  0.186E-01  0.186E-01
#  -10.007  0.169E+00  0.436E-01  0.626E-01  0.626E-01
#   -9.997  0.203E+00  0.146E+00  0.286E-01  0.286E-01
#
# ...
